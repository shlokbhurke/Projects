# %%
from time import sleep #importing package



def strt():
    '''The game is about cyberterrorists
    Limitations:
    1. Limited number of keywords as valid inputs'''
    initialize = input(prompt = "Are you ready to start the game or you want to hear the plot?: ").lower()
    
    lst_strt1 = ["y", "start", "strt", "game", "ready", "rdy"]
    lst_strt2 = ["n", "plot", "plt", "hear"]
    
    if any(word1 in initialize for word1 in lst_strt1):
        level1()
        
    elif any(word2 in initialize for word2 in lst_strt2):
        plot()
        strt()   
            
    else:
        print("\nPlease try again with different keywords in input")
        strt()
   



def fail():
    print("Thank you for playing the game")


    
    
def win():
    #Function for win
    lst_strt2 = ["1", "n", "plot", "plt", "hear"]
    
    print("You won the game, have a wine from your money😛 to celebrate your victory")
    print("© Created by Shlok Bhurke - 11006936. This game was inspired by the movie 'The Net'.")
    win_1 = str(input("""Type, 
               1. 'Plot' to view the plot of the movie
               2. Press Enter to exit\n""").lower())
    if any(word2 in win_1 for word2 in lst_strt2) or win_1 == "1":
        plot()
        print("\n")
    
    else:
        print("")
    

    
    
def plot():
    #movie's plot
    print("""   United States Under Secretary of Defense Michael Bergstrom commits suicide after being 
informed that he has tested positive for HIV. Angela Bennett is a systems analyst in Venice, 
California who telecommutes to Cathedral Software in San Francisco. Her interpersonal relationships 
are almost completely online and on the phone, with the exception of forgettable interactions with 
her neighbors and visits to her mother, who is institutionalized with Alzheimer's disease and often 
forgets who Bennett is. Bennett's co-worker Dale sends her a floppy disk of the game "Mozart's Ghost" 
with a backdoor labeled "π" that permits access to a commonly used computer security system called 
"Gatekeeper" sold by Gregg Microsystems, a software company led by CEO Jeff Gregg. Dale and Bennett 
agree to meet, but the navigation system in Dale's private aircraft malfunctions and it crashes into 
a tower, killing him.

    Bennett travels to Cozumel on vacation, where she meets Jack Devlin. After seducing Bennett, Devlin 
pays a mugger to steal her purse as they walk along the beach. He chases the mugger into the foliage, 
catches the mugger, and roots through the purse to find the disk before shooting the mugger. He takes 
Bennett out on his speedboat to kill her as well, but she finds his gun and confronts him. While fleeing 
with the disk and Devlin's wallet, Bennett's dinghy collides with rocks. She is unconscious in the 
hospital for three days.

    When Bennett wakes up, she finds that the disk is ruined by the sun and all records of her life have 
been deleted: She was checked out of her hotel room in Cancun, her car is no longer at the airport parking 
lot, and her credit cards are invalid. Bennett's home is now empty and listed for sale. Moreover, because 
none of the neighbors remember her, they cannot confirm her identity. Bennett's Social Security number is 
now assigned to a "Ruth Marx", for whom Devlin has entered an arrest record by using the Gatekeeper backdoor 
to hack the police computer system. When Bennett calls her own desk at Cathedral Software, an impostor 
answers and offers Bennett her old life back in exchange for the disk. She contacts the only other person 
who knows her by sight, psychiatrist and former lover Alan Champion. He checks her into a hotel, offers to 
contact a friend at the FBI, and arranges to have her mother moved for her safety.

    Using her knowledge of the backdoor and a password found in Devlin's wallet, Bennett logs into the 
Bethesda Naval Hospital's computers and learns that Under Secretary of Defense Bergstrom, who had opposed 
Gatekeeper's use by the federal government, was murdered by altering the results of his HIV test leading 
to a misdiagnosis. Fellow hacker "Cyberbob" connects π with the "Praetorians", a notorious group of 
cyberterrorists linked to recent computer failures around the country. Bennett and Cyberbob plan to meet, 
but the Praetorians intercept their online chat. Bennett escapes from Devlin—a contract killer for the 
cyberterrorists, but the Praetorians kill Champion by tampering with pharmacy and hospital computer records. 
After Bennett is arrested by the California Highway Patrol, a man identifying himself as Champion's FBI 
friend frees her from jail. She realizes he is an impostor and escapes again.

    Now wanted for murder and thought to be Ruth Marx, Bennett hitchhikes to Cathedral's office where, 
using her impostor's computer, she connects the cyberterrorists to Gregg Microsystems and uncovers their 
scheme: once the Praetorians sabotage an organization's computer system, Gregg sells Gatekeeper to it and 
gains unlimited access through the backdoor. Bennett emails evidence of the backdoor and Gregg's involvement 
with the Praetorians to the FBI from the Moscone Center and tricks Devlin into releasing a virus into Gregg's 
mainframe, destroying Gatekeeper and undoing the erasure of her identity. During a battle on the catwalks of 
the convention center, in which Devlin accidentally kills the Bennett impostor from Cathedral Software (the 
real Ruth Marx), Bennett ambushes Devlin with a fire extinguisher, causing him to fall to his death. Bennett 
regains her identity, home, and life. She then reunites with her mother, and the conspiracy is exposed, with 
Jeff Gregg being arrested by the FBI, live on television.


Source: Wikipedia""")



    
    
    
def level1():
    
    #Level 1 of the game
    
    c_name = input("Please type a name (full name) for your character?: ").title()
    cname_lst = c_name.split()
    print("\nLet's start the game") #delay the print sequence from here on
    sleep(1)
    print(f"\nHi {cname_lst[0]}, it's good to see you! You are a software engineer cum games tester at a firm.")
    sleep(1)


    print("""\nYou love your job so much that in last 7 years you didn't took a single day off.)
    
    Looking at your dedication, your company has offered you a paid international vacation which includes 
everything. Due to security reasons you are also carrying the disk which is couriered by your company 
containing important information.""")
    sleep(5)
    print("\nYou decided to go to Canada")
    sleep(1)
    print("\n...You have reached airport")
    sleep(1)
    print("\n...You boarded the plane...")
    sleep(2)
    print("""
                       ______
                        _\ _~-\___
                =  = ==(____AA____D
                            \_____\___________________,-~~~~~~~`-.._
                            /     o O o o o o O O o o o o o o O o  |\_
The United States           `~-.__        ___..----..                  )           Canada
                                  `---~~\___________/------------`````
                                  =  ===(_________D


""")
    print("You have reached Canada and sitting on a beach")
    sleep(2)
    print("""\nA handsome-looking man starts flirting with you. While talking, you get to know his interests 
          which are similar to yours""")
    lst_l1_1 = ["1", "flirt", "flrt", "back", "bck"]
    lst_l1_2 = ["2", "ignore", "ign", "ignr", "carry", "cry", "on"]
    
    resp_1 = str(input(prompt = """1. Flirt back 
2. Ignore and carry on\n""")).lower()
    if any(response in resp_1 for response in lst_l1_1): 
        print("""\nAfter a bit of a conversation, you found that your interest match and you decided to 
              go on a date with him.""")
        level2()
    elif any(response in resp_1 for response in lst_l1_2):
        print("You are a dull person and the rest of the game is not meant for you.")
        level1()
        chances -= 1
    elif resp_1 == "":
        fail()
    else:
        print(f"'{resp_1}' is an invalid input, please try with different keywords")
        level1()  

    

    
    
def level2():
     
    #Level 2 of the game
    sleep(3)
    print("""\nYour trust was broken!!! Your date threw in water in search of disk you possessed. In the 
          journey, the disk was lost at some point.""")
    sleep(3)
    print("\nYour enemies want to kill you.")
    sleep(2)
    level2_1 = input(prompt = """What do you want to do next?
    1. Contemplate & sulk
    2. Plan on how to return to the United States (your home-country)
    Use one word for the input\n""").lower()
    
    #Lists for keywords
    lst_l2_1 = ["1", "contemplate", "cont", "con", "sulk"]
    lst_l2_2 = ["2","plan", "pln", "return", "united", "states"]
    lst_l2_3 = ["1", "enter", "entr", "country"]
    lst_l2_4 = ["2", "raise", "issue", "isue", "embassy", "wait"]
   
    if any(action1 in level2_1 for action1 in lst_l2_1):
        print("You eventually died, game over")
        level2()
    elif any(action2 in level2_1 for action2 in lst_l2_2):
        print("""\nWhile applying for duplicate documents, you found that with your credentials and fingerprints 
              were wrongly associated to a person with name 'Ruth Marx'. What you want to do next?\n""")
        level2_2 = input(prompt = """1. Enter the country with the identity of Ruth Marx
        2. Raise an issue with the embassy and wait\n""").lower()
        if any(action3 in level2_2 for action3 in lst_l2_3):
            level3()
        elif any(action4 in level2_2 for action4 in lst_l2_4):
            print("\nWe creators like you as a player but next stages are not meant for you.")
            level2()
        else:
            print("Invalid input.")
            level2()
    else:
        print("Invalid input.")
        level2()
        
        


def level3():
    
    #Level 3 of the game
    sleep(2)
    print("You are back to the United States as Ruth Marx.")
    sleep(1)
    print(f"""You found that your identity is being used by the actual Ruth Marx who is 
          amongst the most wanted list in the country. Also, you find that your house was sold.""")
    sleep(4)
    
    
    #Lists for keywords
    lst_l3_1 = ["fight", "fgt", "1", "f"]
    lst_l3_2 = ["ignore", "ign", "ignr"]
    level3_1 = input(prompt = """What you want to do next
                            1. Fight
                            2. Ignore \n""").lower()
    if any(word3 in level3_1 for word3 in lst_l3_1):
        print("""Good that you decided to ignored! As you are the criminal according to the records and 
        cannot take help of the officials.""")
        level4()
    elif any(word4 in level3_1 for word4 in lst_l3_2):
        print("You forgot that you are the criminal according to the records. You are in jail. Try again")
        level3()
    else:
        print("Invalid input.")
        level3()


        
def level4():
    
    #Level 4 of the game
    
    print("""\nTo proceed further in the game, you have to expose the cyber-terrorists. For that, 
    you have to go to your office, where actual Ruth Marx is working on your identity.""")
    sleep(4)
    input(prompt = "Press any key to continue and reach to the office: ")
    print("\nAs your ID was duplicated, you have to walk carefully and avoid security")
     #Lists for keywords
    lst4_1 = ["stairs", "starways", "2"]
    lst4_2 = ["ele", "elevator", "lift", "2"]
    level4_1 = input("""You have to go to Level 4 of the office building, which way you you want to go by?
                        1. Elevators
                        2. Stairways\n""").lower()
    if any(path in level4_1 for path in lst4_2):
        print("You got arrested! Try again")
        level4()
    elif any(path in level4_1 for path in lst4_1):
        print("""Great! You bypassed all the CCTVs and security staff.
              
              The actual Ruth Marx is sitting at your desk and you cannot create conflict. 
              You have to distract everyone.""")
              
        level5()


        
def level5():
     #Lists for keywords
    lst6 = ["trigger","trgr", "fire", "alarm", "alrm"]
    lst7 = ["dance", "drop", "punch"]

    level5_1 = input("""Pick a distraction which will give you enough tim"to copy the files from Ruth Marx's desktop, which will help you to expose them:
                        1. Dance in the corridor
                        2. Drop something heavy on the floor
                        3. Trigger the fire alarm
                        4. Punch someone\n""").lower()
    if any(action9 in level5_1 for action9 in lst6):
        input("\nYou managed to distract and get rid of everyone and get to the desk, press any key to start copying the files: ")
        sleep(1)
        print("\nCopying files: 5% completed...")
        sleep(2)
        print("\n....Copying files: 20% completed....")
        sleep(2)
        print("\n....Copying files: 25% completed....")
        sleep(1)
        print("\n....Copying files: 40% completed....")
        input(prompt = "There was an error, press enter key to try again ")
        print("\nCopying files: 15% completed...")
        sleep(2)
        print("\n...Copying files: 42% completed...")
        sleep(1)
        print("\n...Copying files: 73% completed...")
        sleep(1)
        print("\n...Copying files: 87% completed...")
        sleep(2)
        print("\n...All files are copied\n")
        input(prompt = "Press Enter to expose the cyber-terrorists to media ")
        print("\nAll group of the cyber-terrorist were exposed")
        win()
    elif any(action10 in level5_1 for action10 in lst7):
        print("\nTry again")
        level5()
    else:
        print("Please try again with valid input.")
        fail()
    
level5()
